# %%
import pandas as pd

# %%
df = pd.read_csv('D:/datatest/abalone.csv', header = None)

# %%
df
# Out:
#       0      1      2      3       4       5       6       7   8
# 0     M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.1500  15
# 1     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 2     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 3     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 4     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4172  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4173  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4174  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4175  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4176  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4177 rows x 9 columns]

# %%
df.columns = ['Sex', 'Length', 'Diam', 'Height', 'Whole', 'Shucked', 'Viscera', 'Shell', 'Rings']
df
# Out:
#      Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell  Rings
# 0      M   0.455  0.365   0.095  0.5140   0.2245   0.1010  0.1500     15
# 1      M   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700      7
# 2      F   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100      9
# 3      M   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550     10
# 4      I   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550      7
# ...   ..     ...    ...     ...     ...      ...      ...     ...    ...
# 4172   F   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490     11
# 4173   M   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605     10
# 4174   M   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080      9
# 4175   F   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960     10
# 4176   M   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950     12
#
# [4177 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

# %%
import numpy as np

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix

# %%
y = df['Rings']

X = df.drop('Rings',axis=1)

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=423)

from sklearn.linear_model import LinearRegression

clf_lr = LinearRegression()

clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

mse = np.sqrt(mean_squared_error(pred_lr, y_test))

print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 2.380072522406221

# %%
pred_lr
# Out:
# array([ 5.23352277,  8.96830954,  6.60123158, 10.48969637,  9.45043973,
#        10.09165095,  7.76123457, 10.17845077,  9.34239303,  6.6866507 ,
#        10.51539254,  8.40803384,  8.64545873,  8.06547167, 10.09574943,
#        14.78507862,  8.17592365, 10.12746648,  6.7732198 ,  4.83762554,
#        11.19780036,  6.25632925,  8.64683926,  8.97401453,  8.83885785,
#         5.52669304, 11.62077653,  8.34657511, 12.42861002, 17.09470618,
#         9.35818944,  7.45906377, 10.63606641,  6.64897189, 10.84753806,
#        11.47935429, 14.80949873,  6.89473563,  9.45541381, 11.48154569,
#         9.07437997, 17.5086704 ,  9.87120661,  6.15481954,  9.46742482,
#         9.11669893,  5.15306781,  9.72240203, 12.65146795,  9.87356063,
#        10.10436536, 13.09020092,  8.55169556,  6.90805778,  9.38708455,
#        11.44513827, 12.59825562,  6.75125421, 11.27653204,  7.34013946,
#         6.84117504, 12.66632733, 10.41278221, 17.02563511, 16.39716415,
# ...

# %%
import seaborn as sns
sns.countplot(x='Sex', data=df, palette='Set3')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
num_features = df.select_dtypes(include=[np.number]).columns
sns.pairplot(df[num_features])

# %%
df
# Out:
#       Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell  Rings
# 0       2   0.455  0.365   0.095  0.5140   0.2245   0.1010  0.1500     15
# 1       2   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700      7
# 2       0   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100      9
# 3       2   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550     10
# 4       1   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550      7
# ...   ...     ...    ...     ...     ...      ...      ...     ...    ...
# 4172    0   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490     11
# 4173    2   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605     10
# 4174    2   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080      9
# 4175    0   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960     10
# 4176    2   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950     12
#
# [4177 rows x 9 columns]

# %%
var = 'Shell'
plt.scatter(x=df[var], y=df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Shell']>0.8) & (df['Rings']>25)].index, inplace=True)

# %%
plt.scatter(x=df[var], y=df['Rings'])
plt.grid(True)

# %%
df = pd.read_csv('D:/datatest/wine.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# d:\OneDrive\수업자료\2023-2\데이터처리\source_code\Dataprocessing\2023_11_16.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/%EC%88%98%EC%97%85%EC%9E%90%EB%A3%8C/2023-2/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%B2%98%EB%A6%AC/source_code/Dataprocessing/2023_11_16.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('D:/datatest/wine.csv')
#
# File d:\Anaconda_envs\Probability\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File d:\Anaconda_envs\Probability\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...
