# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

dataset = [['Milk', 'Cola', 'Cookie', 'Bread', 'Jam'],
           ['Ramen', 'Kimchi', 'Rice'],
           ['Ramen', 'Snack', 'Bread', 'Jam'],
           ['Rice', 'Kimchi'],
           ['Cola', 'Bear'],
           ['Cola', 'Cookie', 'Bread'],
           ['Milk', 'Bread', 'Jam'],
           ['Ramen', 'Cheese', 'Ham'],
           ['Bear', 'Snack', 'Cheese', 'Cookie'],
           ['Cookie', 'Bread', 'Jam', 'Snack']]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     Bear  Bread  Cheese   Cola  Cookie    Ham    Jam  Kimchi   Milk  Ramen  \
# 0  False   True   False   True    True  False   True   False   True  False
# 1  False  False   False  False   False  False  False    True  False   True
# 2  False   True   False  False   False  False   True   False  False   True
# 3  False  False   False  False   False  False  False    True  False  False
# 4   True  False   False   True   False  False  False   False  False  False
# 5  False   True   False   True    True  False  False   False  False  False
# 6  False   True   False  False   False  False   True   False   True  False
# 7  False  False    True  False   False   True  False   False  False   True
# 8   True  False    True  False    True  False  False   False  False  False
# 9  False   True   False  False    True  False   True   False  False  False
#
#     Rice  Snack
# 0  False  False
# 1   True  False
# 2  False   True
# 3   True  False
# 4  False  False
# 5  False  False
# 6  False  False
# ...

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemsets['lenght'] = frequent_itemsets['itemsets'].apply(lambda x:len(x))
rules1 = association_rules(frequent_itemsets, metric='lift', min_threshold=0.8)
rules1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\OneDrive\수업자료\2023-2\데이터처리\source_code\Dataprocessing\11_23.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/%EC%88%98%EC%97%85%EC%9E%90%EB%A3%8C/2023-2/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%B2%98%EB%A6%AC/source_code/Dataprocessing/11_23.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/%EC%88%98%EC%97%85%EC%9E%90%EB%A3%8C/2023-2/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%B2%98%EB%A6%AC/source_code/Dataprocessing/11_23.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> frequent_itemsets['lenght'] = frequent_itemsets['itemsets'].apply(lambda x:len(x))
# ...

# %%
frequent_itemsets
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []
