# %%
try:
    from utils import *
except FileNotFoundError:
    # !wget https://raw.githubusercontent.com/dglee6257/Dataprocessing/main/utils.py -O ./utils.py
    from utils import *    

drama = read_csv("top100_kdrama.csv")
drama.head()
# Out:
# --2023-12-13 23:32:23--  https://raw.githubusercontent.com/dglee6257/Dataprocessing/main/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2736 (2.7K) [text/plain]
# Saving to: ‘./utils.py’
#
# ./utils.py          100%[===================>]   2.67K  --.-KB/s    in 0s
#
# 2023-12-13 23:32:23 (69.1 MB/s) - ‘./utils.py’ saved [2736/2736]
#                   Name  Year of release                   Aired Date  \
# 0       Move to Heaven             2021                 May 14, 2021
# 1    Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2       Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3  Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# ...

# %%
drama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   Year of release    100 non-null    int64
#  2   Aired Date         100 non-null    object
#  3   Aired On           100 non-null    object
#  4   Number of Episode  100 non-null    int64
#  5   Network            100 non-null    object
#  6   Duration           100 non-null    object
#  7   Content Rating     100 non-null    object
#  8   Synopsis           100 non-null    object
#  9   Cast               100 non-null    object
#  10  Genre              100 non-null    object
#  11  Tags               100 non-null    object
#  12  Rank               100 non-null    object
#  13  Rating             100 non-null    float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 11.1+ KB

# %%
drama.describe()
# Out:
#        Year of release  Number of Episode      Rating
# count       100.000000         100.000000  100.000000
# mean       2017.970000          19.070000    8.723000
# std           2.869044          12.378096    0.174573
# min        2003.000000           6.000000    8.500000
# 25%        2017.000000          16.000000    8.600000
# 50%        2019.000000          16.000000    8.700000
# 75%        2020.000000          20.000000    8.800000
# max        2021.000000         100.000000    9.200000

# %%
drama['Rating'].describe()
# Out:
# count    100.000000
# mean       8.723000
# std        0.174573
# min        8.500000
# 25%        8.600000
# 50%        8.700000
# 75%        8.800000
# max        9.200000
# Name: Rating, dtype: float64

# %%
d = drama["Content Rating"] == drama["Content Rating"].max()
drama[d]
# Out:
#               Name  Year of release                   Aired Date  \
# 0   Move to Heaven             2021                 May 14, 2021
# 16         Kingdom             2020                 Mar 13, 2020
# 24         Kingdom             2019                 Jan 25, 2019
# 31     Taxi Driver             2021  Apr  9, 2021 - May 29, 2021
# 33       The Guest             2018  Sep 12, 2018 - Nov  1, 2018
# 36           Mouse             2021  Mar  3, 2021 - May 19, 2021
# 37      Sweet Home             2020                 Dec 18, 2020
# 48         My Name             2021                 Oct 15, 2021
# 78      Squid Game             2021                 Sep 17, 2021
# 83        Bad Guys             2014  Oct  4, 2014 - Dec 13, 2014
#
#                 Aired On  Number of Episode   Network       Duration  \
# 0                 Friday                 10  Netflix         52 min.
# 16                Friday                  6  Netflix         45 min.
# ...

# %%
d = drama["Content Rating"] == drama["Content Rating"].min()
drama[d]
# Out:
#                    Name  Year of release                   Aired Date  \
# 64  Jewel in the Palace             2003  Sep 15, 2003 - Mar 23, 2004
# 91         Yumi's Cells             2021  Sep 17, 2021 - Oct 30, 2021
#
#              Aired On  Number of Episode Network       Duration  \
# 64    Monday, Tuesday                 54    MBC    1 hr. 5 min.
# 91   Friday, Saturday                 14    tvN   1 hr. 10 min.
#
#               Content Rating  \
# 64  13+ - Teens 13 or older
# 91  13+ - Teens 13 or older
#
#                                              Synopsis  \
# 64  About 500 years ago during the time of Chosun ...
# 91  Controlled by a complex network of cells, each...
#
#                                                  Cast  \
# 64  Lee Young Ae, Ji Jin Hee, Hong Ri Na, Im Ho, Y...
# 91  Kim Go Eun, Ahn Bo Hyun, Park Ji Hyun, Lee Yoo...
#
#                                         Genre  \
# 64     Food,  Historical,  Romance,  Medical
# ...

# %%
d = drama['Name'].str.contains('Love')
drama[d]
# Out:
#                       Name  Year of release                   Aired Date  \
# 52             Moon Lovers             2016  Aug 29, 2016 - Nov  1, 2016
# 60  It's Okay, That's Love             2014  Jul 23, 2014 - Sep 11, 2014
# 70   My Love from the Star             2013  Dec 18, 2013 - Feb 27, 2014
# 77     Just Between Lovers             2017  Dec 11, 2017 - Jan 30, 2018
#
#                 Aired On  Number of Episode Network       Duration  \
# 52       Monday, Tuesday                 20    SBS         60 min.
# 60   Wednesday, Thursday                 16    SBS         60 min.
# 70   Wednesday, Thursday                 21    SBS         58 min.
# 77       Monday, Tuesday                 16   jTBC   1 hr. 13 min.
#
#               Content Rating  \
# 52  15+ - Teens 15 or older
# 60  15+ - Teens 15 or older
# 70  15+ - Teens 15 or older
# 77  15+ - Teens 15 or older
#
#                                              Synopsis  \
# ...

# %%
drama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   Year of release    100 non-null    int64
#  2   Aired Date         100 non-null    object
#  3   Aired On           100 non-null    object
#  4   Number of Episode  100 non-null    int64
#  5   Network            100 non-null    object
#  6   Duration           100 non-null    object
#  7   Content Rating     100 non-null    object
#  8   Synopsis           100 non-null    object
#  9   Cast               100 non-null    object
#  10  Genre              100 non-null    object
#  11  Tags               100 non-null    object
#  12  Rank               100 non-null    object
#  13  Rating             100 non-null    float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 11.1+ KB

# %%
d = (drama["Number of Episode"] <= 10) & (drama["Rating"] >= 9.0)
drama[d]
# Out:
#              Name  Year of release    Aired Date Aired On  Number of Episode  \
# 0  Move to Heaven             2021  May 14, 2021   Friday                 10
#
#     Network Duration                          Content Rating  \
# 0  Netflix   52 min.  18+ Restricted (violence & profanity)
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
#
#                                                 Cast                   Genre  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...  Life,  Drama,  Family
#
#                                                 Tags Rank  Rating
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...   #1     9.2

# %%
d = drama["Synopsis"].str.contains("Korea")
drama[d]
# Out:
#                      Name  Year of release                   Aired Date  \
# 8               Mr. Queen             2020  Dec 12, 2020 - Feb 14, 2021
# 13               Vincenzo             2021  Feb 20, 2021 - May  2, 2021
# 14   Crash Landing on You             2019  Dec 14, 2019 - Feb 16, 2020
# 17           Mr. Sunshine             2018  Jul  7, 2018 - Sep 30, 2018
# 23                   D.P.             2021                 Aug 27, 2021
# 27        The Devil Judge             2021  Jul  3, 2021 - Aug 22, 2021
# 37             Sweet Home             2020                 Dec 18, 2020
# 39     Chicago Typewriter             2017  Apr  7, 2017 - Jun  3, 2017
# 52            Moon Lovers             2016  Aug 29, 2016 - Nov  1, 2016
# 62        The Bridal Mask             2012  May 30, 2012 - Sep  6, 2012
# 64    Jewel in the Palace             2003  Sep 15, 2003 - Mar 23, 2004
# 70  My Love from the Star             2013  Dec 18, 2013 - Feb 27, 2014
# ...

# %%
d = drama.groupby(["Year of release", "Network"])["Number of Episode"].count()
pd.DataFrame(d)
# Out:
#                                  Number of Episode
# Year of release Network
# 2003            MBC                              1
# 2012            KBS2                             1
#                 tvN                              1
# 2013            MBC                              1
#                 SBS                              3
#                 jTBC                             1
# 2014            KBS2                             1
#                 OCN                              1
#                 SBS                              1
#                 tvN                              1
# 2015            MBC                              1
#                 SBS                              1
#                 tvN                              1
# 2016            KBS2                             1
#                 MBC                              1
#                 SBS                              2
#                 jTBC                             1
# ...

# %%
d = drama.groupby(["Year of release", "Network"])["Genre"].count()
pd.DataFrame(d)
# Out:
#                                  Genre
# Year of release Network
# 2003            MBC                  1
# 2012            KBS2                 1
#                 tvN                  1
# 2013            MBC                  1
#                 SBS                  3
#                 jTBC                 1
# 2014            KBS2                 1
#                 OCN                  1
#                 SBS                  1
#                 tvN                  1
# 2015            MBC                  1
#                 SBS                  1
#                 tvN                  1
# 2016            KBS2                 1
#                 MBC                  1
#                 SBS                  2
#                 jTBC                 1
#                 tvN                  3
# 2017            KBS2                 4
#                 MBC                  1
#                 Netflix,  tvN        2
#                 OCN                  2
# ...
