# %%
import pandas as pd
df = pd.read_excel('D:/datatest/fo.xlsx')
df
# Out:
#      이름  당도  아삭함   종류
# 0   오렌지   7    3   과일
# 1    포도   8    5   과일
# 2   견과류   3    6  단백질
# 3    새우   2    3  단백질
# 4    생선   3    1  단백질
# 5     콩   3    7   채소
# 6   베이컨   1    4  단백질
# 7   바나나  10    1   과일
# 8     배  10    7   과일
# 9    오이   2    8   채소
# 10   치즈   1    1  단백질
# 11   당근   5   10   채소
# 12   사과  10    9   과일
# 13  샐러리   3   10   채소
# 14  양상추   1    9   채소

# %%
df = df.drop(['종류', '이름'], axis=1)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#     당도  아삭함
# 0    7    3
# 1    8    5
# 2    3    6
# 3    2    3
# 4    3    1
# 5    3    7
# 6    1    4
# 7   10    1
# 8   10    7
# 9    2    8
# 10   1    1
# 11   5   10
# 12  10    9
# 13   3   10
# 14   1    9

# %%
temp = []
for i in range(2, 8):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df)
    temp.append(kmeans.inertia_)
plt.plot(range(2, 8), temp)

# %%
df = pd.read_excel('D:/datatest/fo.xlsx')
df
# Out:
#      이름  당도  아삭함   종류
# 0   오렌지   7    3   과일
# 1    포도   8    5   과일
# 2   견과류   3    6  단백질
# 3    새우   2    3  단백질
# 4    생선   3    1  단백질
# 5     콩   3    7   채소
# 6   베이컨   1    4  단백질
# 7   바나나  10    1   과일
# 8     배  10    7   과일
# 9    오이   2    8   채소
# 10   치즈   1    1  단백질
# 11   당근   5   10   채소
# 12   사과  10    9   과일
# 13  샐러리   3   10   채소
# 14  양상추   1    9   채소

# %%
import sklearn.preprocessing.LabelEncoder

label=LabelEncoder()

df['이름']=label.fit_transform(df['이름'])
df['종류']=label.fit_transform(df['종류'])

df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\OneDrive\수업자료\2023-2\데이터처리\source_code\Dataprocessing\12_07.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/%EC%88%98%EC%97%85%EC%9E%90%EB%A3%8C/2023-2/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%B2%98%EB%A6%AC/source_code/Dataprocessing/12_07.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import sklearn.preprocessing.LabelEncoder
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/%EC%88%98%EC%97%85%EC%9E%90%EB%A3%8C/2023-2/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%B2%98%EB%A6%AC/source_code/Dataprocessing/12_07.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> label=LabelEncoder()
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/%EC%88%98%EC%97%85%EC%9E%90%EB%A3%8C/2023-2/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%B2%98%EB%A6%AC/source_code/Dataprocessing/12_07.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> df['이름']=label.fit_transform(df['이름'])
#
# ...

# %%
from yellowbrick.cluster import KElbowVisualizer
data = df[['당도', '아삭함']].iloc[:, :].values
model = KMeans()
