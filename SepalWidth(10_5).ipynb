# %%
import os

data_folder = "./datatest/"
if not (os.path.exists(data_folder) and os.path.isdir(data_folder)):
    data_folder = "https://raw.githubusercontent.com/dglee6257/Dataprocessing/main/datatest/"

data_folder
# Out:
# './datatest/'

# %%
def folder_path(s):
    return os.path.join(data_folder, s)

# Test folder_path
folder_path('aaa.csv')
# Out:
# './datatest/aaa.csv'

# %%
import pandas as pd
import os

# %%
df = pd.read_csv(folder_path('music.csv'))
df
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
newdata = df.groupby('agency').count()
pd.DataFrame(newdata['personnel'])
# Out:
#                        personnel
# agency
# JYP엔터테인먼트                      1
# SM엔터테인먼트                       2
# YG엔터테인먼트                       3
# YMC엔터테인먼트, 스톤뮤직엔터테인먼트          1
# 바나나컬쳐                          1
# 빅히트뮤직                          2
# 쏘스뮤직                           1
# 울림엔터테인먼트                       1
# 카카오엔터테인먼트                      1

# %%
newdata = df.groupby(['agency']).sum()
pd.DataFrame(newdata['personnel'])
# Out:
#                        personnel
# agency
# JYP엔터테인먼트                      5
# SM엔터테인먼트                      10
# YG엔터테인먼트                       9
# YMC엔터테인먼트, 스톤뮤직엔터테인먼트         11
# 바나나컬쳐                          4
# 빅히트뮤직                         14
# 쏘스뮤직                           6
# 울림엔터테인먼트                       8
# 카카오엔터테인먼트                      1

# %%
df = pd.read_csv(folder_path('titanic.csv'))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Age'].isna()].head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 5             6         0       3
# 17           18         1       2
# 19           20         1       3
# 26           27         0       3
# 28           29         1       3
# 29           30         0       3
# 31           32         1       1
# 32           33         1       3
# 36           37         1       3
# 42           43         0       3
#
#                                               Name     Sex  Age  SibSp  Parch  \
# 5                                 Moran, Mr. James    male  NaN      0      0
# 17                    Williams, Mr. Charles Eugene    male  NaN      0      0
# 19                         Masselmani, Mrs. Fatima  female  NaN      0      0
# 26                         Emir, Mr. Farred Chehab    male  NaN      0      0
# 28                   O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0      0
# 29                             Todoroff, Mr. Lalio    male  NaN      0      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Cabin'].fillna('-', inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
import matplotlib.pyplot as plt
plt.title('Square Graph')
xdata = [1, 2, 3, 4, 5, 6]
ydata = [1, 4, 9, 16, 25, 36]
plt.plot(xdata, ydata)
plt.show()

# %%
import pandas as pd
data = pd.read_excel(folder_path('04_data1.xlsx'), index_col = 'area')
data.head()
# Out:
#               2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide         72.0         54         84        135        117
# Metropolitan       72.0         45         77        126        109
# Seoul              97.0         65        113        140        139
# Busan             102.0         89         86        136        163
# Daegu              90.0        103        111        155        148
#
#               2020_good  2015_common  2016_common  2017_common  2018_common  \
# area
# Nationwide          171        267.0          297          265          209
# Metropolitan        150        259.0          290          260          217
# Seoul               168        243.0          277          230          204
# Busan               208        242.0          259          269          212
# Daegu               176        248.0          246          244          196
#
#               ...  2017_bad  2018_bad  2019_bad  2020_bad  2015_verybad  \
# ...

# %%
data2020_good = data['2020_good']
data2019_good = data['2019_good']

# %%
plt.figure(figsize=(20, 4))
plt.plot(data2020_good,  color='b', marker='s', label='2020')
plt.plot(data2019_good,  color='r', marker='s', label='2019')
plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.title('2019&2020 Fine Dust(pm10) Good Line Graph')
plt.legend()
plt.grid()
plt.show()

# %%
data2015_verybad = data['2015_verybad']
data2019_verybad = data['2019_verybad']

plt.figure(figsize=(20,  4))
plt.bar(data2015_verybad.index, data2015_verybad, color='g', label='2015')
plt.bar(data2019_verybad.index, data2019_verybad, color='r', label='2019')
plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.title('2015&2019 Fine Dust(pm10) Good Line Graph')
plt.legend()
plt.grid()
plt.show()

# %%
data = pd.read_excel(folder_path('04_data1.xlsx'))
data
# Out:
#             area  2015_good  2016_good  2017_good  2018_good  2019_good  \
# 0     Nationwide       72.0         54         84        135        117
# 1   Metropolitan       72.0         45         77        126        109
# 2          Seoul       97.0         65        113        140        139
# 3          Busan      102.0         89         86        136        163
# 4          Daegu       90.0        103        111        155        148
# 5        Incheon       67.0         49         78        140        115
# 6        Gwangju      122.0        151        134        149        117
# 7        Daejeon      111.0         92         83        121        143
# 8          Ulsan      101.0        101        104        162        173
# 9         Sejong        NaN         65         69        130        127
# 10      Gyeonggi       65.0         45         59        123         97
# 11       Gangwon       77.0         65        108        150        159
# ...

# %%
data = data.set_index('area')
data
# Out:
#               2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide         72.0         54         84        135        117
# Metropolitan       72.0         45         77        126        109
# Seoul              97.0         65        113        140        139
# Busan             102.0         89         86        136        163
# Daegu              90.0        103        111        155        148
# Incheon            67.0         49         78        140        115
# Gwangju           122.0        151        134        149        117
# Daejeon           111.0         92         83        121        143
# Ulsan             101.0        101        104        162        173
# Sejong              NaN         65         69        130        127
# Gyeonggi           65.0         45         59        123         97
# Gangwon            77.0         65        108        150        159
# Chungbuk           90.0         99        106        117        113
# ...

# %%
data1 = data.loc[['Seoul', 'Busan', 'Daegu'], ['2015_good', '2018_good', '2020_good']]
data1
# Out:
#        2015_good  2018_good  2020_good
# area
# Seoul       97.0        140        168
# Busan      102.0        136        208
# Daegu       90.0        155        176

# %%
data1.index, data1.columns
# Out:
# (Index(['Seoul', 'Busan', 'Daegu'], dtype='object', name='area'),
#  Index(['2015_good', '2018_good', '2020_good'], dtype='object'))

# %%
import numpy as np
import matplotlib.pyplot as plt


species = data1.index

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots(nrows=1, ncols=1, layout='constrained', figsize=(12, 8))

for index, column in enumerate(data1.columns):
    offset = width * index
    rects = ax.bar(x + offset, data1[column], width, label=column)
    ax.bar_label(rects, padding=3)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
data6 = data.loc['Seoul':'Ulsan', '2015_good':'2020_good']
data6
# Out:
#          2015_good  2016_good  2017_good  2018_good  2019_good  2020_good
# area
# Seoul         97.0         65        113        140        139        168
# Busan        102.0         89         86        136        163        208
# Daegu         90.0        103        111        155        148        176
# Incheon       67.0         49         78        140        115        182
# Gwangju      122.0        151        134        149        117        210
# Daejeon      111.0         92         83        121        143        182
# Ulsan        101.0        101        104        162        173        206

# %%
import numpy as np
index = np.arange(7)

plt.figure(figsize=(20, 4))

data6 = data.loc['Seoul':'Ulsan', '2015_good':'2020_good']
for year in range(2015, 2021):
    year = str(year)+'_good'
    chartdata = data6[year]
    plt.bar(index, chartdata, width=0.15, label=year)
    index = index + 0.15

plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.xticks(index-0.53, data6.index)
plt.title('2015&2020 Fine Dust(pm10) Good Line Graph')
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
data = pd.read_csv(folder_path('04_data2.csv'))
data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
versicolor_SepalWidth = data.loc[data.Species == 'versicolor', ['Species', 'SepalWidth']]
virginica_SepalWidth = data.loc[data.Species=='virginica', ['Species', 'SepalWidth']]

plt.figure(figsize=(10, 6))
plt.hist(versicolor_SepalWidth['SepalWidth'], bins=5, alpha=0.5, label='versicolor', color='r')
plt.hist(virginica_SepalWidth['SepalWidth'], bins=5, alpha=0.5, label='virginica', color='b')

plt.xlabel('Sepal')
plt.ylabel('Width')
plt.title('Iris Petal Group Histogram')
plt.legend()
plt.grid()
plt.show()
